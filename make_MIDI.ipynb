# %% [markdown]
# # Python 2

# %%
import sys
sys.path
sys.path.append('./midi')

import midi
from midi.utils import midiwrite
import numpy as np

piano_roll = np.random.rand(61, 79) < .5 # let's randomly generate some piano roll with 61 notes and 79 time points
# midi.utils.midiwrite('piano_roll.mid', piano_roll.T, (32, 93), 0.25) 
midiwrite('piano_roll.mid', piano_roll.T, (32, 93), 0.25) 
# 3rd arg is the start and end notes; 4rth arg is time between samples

# %% [markdown]
# # Py 3

# %%
from midi2audio import FluidSynth

# %%
FluidSynth().play_midi('piano_roll.mid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-30e14e665f61> in <module>()
# ----> 1 FluidSynth().play_midi('piano_roll.mid')
#
# ~/anaconda3/envs/NIPS/lib/python3.6/site-packages/midi2audio.py in play_midi(self, midi_file)
#      47
#      48     def play_midi(self, midi_file):
# ---> 49         subprocess.call(['fluidsynth', '-i', self.sound_font, midi_file, '-r', str(self.sample_rate)])
#      50
#      51 def parse_args(allow_synth=True):
#
# ~/anaconda3/envs/NIPS/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     265     retcode = call(["ls", "-l"])
#     266     """
# --> 267     with Popen(*popenargs, **kwargs) as p:
#     268         try:
#     269             return p.wait(timeout=timeout)
#
# ~/anaconda3/envs/NIPS/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# ~/anaconda3/envs/NIPS/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1342                         if errno_num == errno.ENOENT:
#    1343                             err_msg += ': ' + repr(err_filename)
# -> 1344                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1345                 raise child_exception_type(err_msg)
#    1346
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fluidsynth': 'fluidsynth'
